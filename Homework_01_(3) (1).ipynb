# %% [markdown]
# # Homework 01: Binary Classification with Neural Networks
#
# ## Due: Sunday September 7 @ 11:59 (with 2-hour grace period) and worth 85 points
#
# In this assignment, you'll build your first deep learning models using **Keras**, a high-level deep learning framework built on TensorFlow.
#
# We’ll solve a binary classification task, using the Wisconsin Breast Cancer dataset.
#
# You’ll start by training a simple baseline model, and then explore a series of alternate network designs.  For each model, you’ll:
#
# - Track training loss and accuracy over epochs
# - Report final test set performance (loss and accuracy)
#
# The goal is to begin developing an intuition for how network design choices influence performance—and to get comfortable with the end-to-end modeling workflow in Keras.
#
#
# There are 12 graded problems, each worth 7 points, and you get 1 point free.

# %%
# Useful Imports

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.utils import class_weight

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Sequential

random_seed = 42

# %%
# Utility function: Plotting Training Loss (x-entropy) and Accuracy
# We'll replace this with a different function train_and_test when we develop more
# training techniques.

# Takes the history object returned by fit

def plot_history(history):
    n_epochs = len(history.history['accuracy'])
    epochs = range(1, n_epochs + 1)

    plt.figure(figsize=(7, 8))

    plt.subplot(2, 1, 1)
    plt.plot(epochs, history.history['loss'], label='Training Loss (Xent)', color='tab:red')
    plt.ylabel('Loss')
    plt.title('Training Loss')
    plt.grid(True)
    plt.legend()

    plt.subplot(2, 1, 2)
    plt.plot(epochs, history.history['accuracy'], label='Training Accuracy', color='tab:blue')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.ylim(0, 1.05)
    plt.title('Training Accuracy')
    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()

    final_loss = history.history['loss'][-1]
    final_acc = history.history['accuracy'][-1]
    print(f'Final Training Loss:     {final_loss:.4f}')
    print(f'Final Training Accuracy: {final_acc:.4f}')

# %% [markdown]
# ## Prelude: Load and Explore the Wisconsin Breast Cancer Dataset
#
# You should **always** perform EDA when working with a new dataset. We've seen this one before, but its always worth becoming familiar with the data before building a model!

# %%
# Load dataset with as DataFrame for EDA
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer(as_frame=True)

df = data.frame  # Convenient alias for combined data+target

# %%
# Uncomment and look at this

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
#  13  area error               569 non-null    float64
#  14  smoothness error         569 non-null    float64
#  15  compactness error        569 non-null    float64
#  16  concavity error          569 non-null    float64
#  17  concave points error     569 non-null    float64
#  18  symmetry error           569 non-null    float64
#  19  fractal dimension error  569 non-null    float64
#  20  worst radius             569 non-null    float64
#  21  worst texture            569 non-null    float64
#  22  worst perimeter          569 non-null    float64
#  23  worst area               569 non-null    float64
#  24  worst smoothness         569 non-null    float64
#  25  worst compactness        569 non-null    float64
#  26  worst concavity          569 non-null    float64
#  27  worst concave points     569 non-null    float64
#  28  worst symmetry           569 non-null    float64
#  29  worst fractal dimension  569 non-null    float64
#  30  target                   569 non-null    int64
# dtypes: float64(30), int64(1)
# memory usage: 137.9 KB

# %%
df.shape
# Out:
# (569, 31)

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
#
# [5 rows x 31 columns]

# %%
df.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# target                     0
# dtype: int64

# %%
corr = df.corr()
plt.figure(figsize=(15, 12))
sns.heatmap(
    corr,
    annot=False,
    cmap='coolwarm',
    cbar=True
)

plt.title("Correlation Heatmap - Breast Cancer Dataset", fontsize=20)
plt.show()

# %%
# Uncomment and look at this

fig = df.hist(bins=20, figsize=(20, 15), layout=(6, 6))
plt.suptitle("\nHistograms of All Features in Breast Cancer Dataset", fontsize=32)
plt.tight_layout(rect=[0, 0, 1, 0.95])  # Leave space for the title
plt.show()

# %% [markdown]
# ## Problem One: Dealing with unbalanced target variables and establishing a baseline model
#
# ### Part A: Compute the imbalance of the target
#
# Neural networks work best with standardized datasets; for classification tasks, it is also important
# to account for an unbalanced target. Let's create our `X,y` data structure and look at the target more closely.
#
# 1. **Convert the data to NumPy arrays:** Extract the feature matrix `X` and the target vector `y` from the DataFrame, and
# convert them to NumPy arrays. Print the shapes of `X` and `y` to confirm the conversion was successful.
#
# 2. **Check for class imbalance:**
#    Use `Counter` (or another appropriate method) to print the frequency of each class label in the target array `y`. This will help you understand how balanced (or imbalanced) the classes are.
#
# 3. **Compute the proportion of class 1:**
#    Calculate what percentage of the samples belong to class label `1` and provide your answer in the graded question.

# %%
# A.1

#Your code here

# Extract X (features) and y (target) and convert to NumPy arrays
X = df.drop(columns='target').values
y = df['target'].values

# Confirm shapes
print("Shape of X (features):", X.shape)
print("Shape of y (target):", y.shape)
# Out:
# Shape of X (features): (569, 30)
# Shape of y (target): (569,)

# %%
# A.2

# Your code here
# Count the frequency of each class in y
class_counts = Counter(y)

print("Frequency of each class:")
total_samples = len(y)
for cls, count in class_counts.items():
    print(f"Class {cls}: {count} samples ({count/total_samples:.2%})")
# Out:
# Frequency of each class:
# Class 0: 212 samples (37.26%)
# Class 1: 357 samples (62.74%)

# %%
# Assume y is already our target NumPy array
count_class_1 = sum(y == 1)
total_samples = len(y)
percentage_class_1 = (count_class_1 / total_samples) * 100

# %%
# A.3

# Set a1a to the percentage (a float between 0 and 1) of 1's in the target
# Use an expression, not constants derived from inspecting the data

a1a = count_class_1 / total_samples            # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way

print(f'a1a = {a1a:.4f}')
# Out:
# a1a = 0.6274

# %% [markdown]
# ### Part B: Perform a stratified test/train split
#
# In classification problems with imbalanced datasets, it's important to address the class imbalance so that the model doesn't become biased toward the majority class. There are two common strategies:
#
# * **Resampling** the dataset to balance the classes (by oversampling the minority class or undersampling the majority class).
# * **Adjusting the loss function** so that errors on minority classes have more influence during training.
#
# In this problem, you'll explore the second approach—using class weights to influence how the model learns.
#
# This strategy involves two key steps:
#
# 1. **Preserve class proportions in the train/test split**
#    Use the  parameter `stratify=y`in `train_test_split` to ensure that both the training and testing sets maintain the same class distribution as in the original target.
#
# 2. **Apply class weighting during training**
#    Use the `class_weight` parameter in the `fit` function to assign different weights to each class when computing the loss. This helps ensure that the model pays appropriate attention to both common and rare classes.
#
#
# **We'll do the first step now, perform standardization, and then do the second step in Part C.**

# %%
# Perform train-test split, keeping both stratified, use random_state = random_seed and test_size = 0.2

# Your code here
# X = features, y = target
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,     # 20% of the data for testing
    random_state=random_seed,   # makes the split reproducible
    stratify=y         # <--- this keeps the class proportions the same
)

# %% [markdown]
# **(Digression:** We must perform standardization **after** the test/train split, or else we're letting
# information about the mean and standard deviation of the test set influence training--a classic case of *data leakage*.
# **)**

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# As usual, standardize the features

# Your code here
from sklearn.linear_model import LogisticRegression
# Create a model that uses balanced class weights
model = LogisticRegression(class_weight='balanced', max_iter=1000)

# Train the model
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %% [markdown]
# Let's see if the stratification worked! Assign `a1b` to the percentage of 1's in `y_train` (and convince yourself that if it is approximately correct, then so must be `y_test`).

# %%
# Set a1b to the percentage (a float between 0 and 1) of 1's in the target
# Use an expression, not constants derived from inspecting the data

# Percentage of class 1 in training set
a1b = (sum(y_train == 1) / len(y_train))            # Replace 0.0 with your answer

print(f"Percentage of class 1 in y_train: {a1b:.2f}%")
# Out:
# Percentage of class 1 in y_train: 0.63%

# %%
# Graded Answer
# DO NOT change this cell in any way

print(f'a1b = {a1b:.4f}')
# Out:
# a1b = 0.6264

# %% [markdown]
# ## Part C: Train a baseline model with class weighting
#
# Now we'll build a baseline model with class weighting during training.
#
# To compute the weight for class $i$, use the following formula:
#
# $$
# \text{weight}_i = \frac{n}{k \cdot n_i},
# $$
#
# where:
#
# * $n$ is the total number of samples,
# * $n_i$ is the number of samples in class $i$,
# * $k$ is the total number of classes.
#
# This formula scales the loss so that each class contributes approximately equally during training—without changing the number of training samples.
#
# To apply class weighting during training, we use the parameter `class_weight=weights` in the `fit` function, where `weights` is a dictionary
#
#     { 0 : weight_0, 1 : weight_1 }
#
# as specified in the formula above.
#
# **Note**: As an alternative, you can also use `sklearn.utils.class_weight` to do the calculation.
#
# **TODO: Complete the template to**
#
# -  Build a network consisting of a single logistic regression classifier (done for you!)
# -  Compile it using the same parameters as shown in the coding video, except we will use the `Adam` optimizer:
# >          optimizer='adam'
# -  Train it for **100** epochs, calculating the class weights explicitly as shown or using `sklearn.utils.class_weight` (look up the docs!)
# -  Display the training loss and accuracy curves using `plot_history`
# -  Complete the graded question

# %%
# Try a baseline model consisting of a single logistic regression classifier.
# This is very similar to sklearn's LogisticRegression model.

n_epochs = 100

# We use Sequential to build a simple classification network from
# a list of layers, and print the summary

# Uncomment this when you have defined X_train:


model_baseline = keras.Sequential(
    [
       keras.layers.Input(shape=(X_train.shape[1],)),     # Explicit input layer
       keras.layers.Dense(1, activation="sigmoid")
    ]
)


# Your code here, add additional cells if you wish
model_baseline.summary()

model_baseline.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Calculate class weights
classes = np.unique(y_train)
class_weights_array = class_weight.compute_class_weight('balanced', classes=classes, y=y_train)
class_weights = {i : class_weights_array[i] for i in range(len(classes))}


history = model_baseline.fit(
    X_train_scaled,   # standardized features
    y_train,
    epochs=n_epochs, # Use the defined n_epochs
    batch_size=32,
    validation_split=0.2,
    class_weight=class_weights,
    verbose=1
)

plot_history(history)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31 (124.00 B)
#  Trainable params: 31 (124.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5437 - loss: 0.7735 - val_accuracy: 0.5055 - val_loss: 0.7854
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6128 - loss: 0.6855 - val_accuracy: 0.5495 - val_loss: 0.7241
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6920 - loss: 0.6394 - val_accuracy: 0.6044 - val_loss: 0.6703
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6778 - loss: 0.6371 - val_accuracy: 0.6484 - val_loss: 0.6235
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7155 - loss: 0.5739 - val_accuracy: 0.6813 - val_loss: 0.5818
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7639 - loss: 0.5160 - val_accuracy: 0.6813 - val_loss: 0.5469
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7552 - loss: 0.5231 - val_accuracy: 0.7143 - val_loss: 0.5143
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7851 - loss: 0.4642 - val_accuracy: 0.7363 - val_loss: 0.4853
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8159 - loss: 0.3986 - val_accuracy: 0.7582 - val_loss: 0.4607
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8143 - loss: 0.4138 - val_accuracy: 0.7802 - val_loss: 0.4377
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8325 - loss: 0.3937 - val_accuracy: 0.7912 - val_loss: 0.4176
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8181 - loss: 0.4039 - val_accuracy: 0.8242 - val_loss: 0.3986
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8737 - loss: 0.3288 - val_accuracy: 0.8681 - val_loss: 0.3815
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8885 - loss: 0.3193 - val_accuracy: 0.8681 - val_loss: 0.3664
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8774 - loss: 0.3339 - val_accuracy: 0.8791 - val_loss: 0.3521
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8804 - loss: 0.3174 - val_accuracy: 0.8791 - val_loss: 0.3382
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8618 - loss: 0.3460 - val_accuracy: 0.8901 - val_loss: 0.3254
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9109 - loss: 0.2997 - val_accuracy: 0.8901 - val_loss: 0.3141
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9155 - loss: 0.2796 - val_accuracy: 0.8901 - val_loss: 0.3031
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9100 - loss: 0.2954 - val_accuracy: 0.8901 - val_loss: 0.2924
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9281 - loss: 0.2692 - val_accuracy: 0.8901 - val_loss: 0.2828
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9141 - loss: 0.2657 - val_accuracy: 0.9011 - val_loss: 0.2739
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9302 - loss: 0.2443 - val_accuracy: 0.9011 - val_loss: 0.2657
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9129 - loss: 0.2546 - val_accuracy: 0.9011 - val_loss: 0.2573
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9011 - loss: 0.2720 - val_accuracy: 0.9011 - val_loss: 0.2502
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9144 - loss: 0.2534 - val_accuracy: 0.9011 - val_loss: 0.2428
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9209 - loss: 0.2363 - val_accuracy: 0.9231 - val_loss: 0.2362
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9128 - loss: 0.2370 - val_accuracy: 0.9231 - val_loss: 0.2296
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9258 - loss: 0.2426 - val_accuracy: 0.9341 - val_loss: 0.2237
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9433 - loss: 0.2096 - val_accuracy: 0.9341 - val_loss: 0.2188
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9284 - loss: 0.2145 - val_accuracy: 0.9341 - val_loss: 0.2127
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9369 - loss: 0.2205 - val_accuracy: 0.9341 - val_loss: 0.2076
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9331 - loss: 0.2066 - val_accuracy: 0.9341 - val_loss: 0.2029
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9512 - loss: 0.1867 - val_accuracy: 0.9341 - val_loss: 0.1985
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9163 - loss: 0.2277 - val_accuracy: 0.9341 - val_loss: 0.1940
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9351 - loss: 0.1999 - val_accuracy: 0.9341 - val_loss: 0.1900
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9330 - loss: 0.1874 - val_accuracy: 0.9341 - val_loss: 0.1861
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9243 - loss: 0.2032 - val_accuracy: 0.9341 - val_loss: 0.1825
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9509 - loss: 0.1832 - val_accuracy: 0.9341 - val_loss: 0.1790
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9451 - loss: 0.1789 - val_accuracy: 0.9341 - val_loss: 0.1756
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9267 - loss: 0.2012 - val_accuracy: 0.9451 - val_loss: 0.1724
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9588 - loss: 0.1751 - val_accuracy: 0.9451 - val_loss: 0.1691
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9464 - loss: 0.1950 - val_accuracy: 0.9451 - val_loss: 0.1664
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9428 - loss: 0.1793 - val_accuracy: 0.9560 - val_loss: 0.1634
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9459 - loss: 0.1804 - val_accuracy: 0.9560 - val_loss: 0.1608
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9620 - loss: 0.1701 - val_accuracy: 0.9560 - val_loss: 0.1582
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9513 - loss: 0.1636 - val_accuracy: 0.9670 - val_loss: 0.1557
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9515 - loss: 0.1638 - val_accuracy: 0.9670 - val_loss: 0.1534
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9615 - loss: 0.1532 - val_accuracy: 0.9670 - val_loss: 0.1511
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9507 - loss: 0.1686 - val_accuracy: 0.9670 - val_loss: 0.1489
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9702 - loss: 0.1293 - val_accuracy: 0.9670 - val_loss: 0.1469
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9659 - loss: 0.1565 - val_accuracy: 0.9670 - val_loss: 0.1447
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9674 - loss: 0.1457 - val_accuracy: 0.9670 - val_loss: 0.1427
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9537 - loss: 0.1633 - val_accuracy: 0.9670 - val_loss: 0.1407
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9680 - loss: 0.1390 - val_accuracy: 0.9670 - val_loss: 0.1387
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9573 - loss: 0.1631 - val_accuracy: 0.9670 - val_loss: 0.1369
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9651 - loss: 0.1350 - val_accuracy: 0.9670 - val_loss: 0.1353
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9691 - loss: 0.1390 - val_accuracy: 0.9670 - val_loss: 0.1337
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9656 - loss: 0.1399 - val_accuracy: 0.9670 - val_loss: 0.1320
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9568 - loss: 0.1491 - val_accuracy: 0.9780 - val_loss: 0.1305
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9554 - loss: 0.1425 - val_accuracy: 0.9780 - val_loss: 0.1290
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9546 - loss: 0.1413 - val_accuracy: 0.9780 - val_loss: 0.1275
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9694 - loss: 0.1273 - val_accuracy: 0.9780 - val_loss: 0.1260
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9646 - loss: 0.1328 - val_accuracy: 0.9780 - val_loss: 0.1246
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9577 - loss: 0.1267 - val_accuracy: 0.9780 - val_loss: 0.1233
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9667 - loss: 0.1277 - val_accuracy: 0.9780 - val_loss: 0.1220
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9626 - loss: 0.1410 - val_accuracy: 0.9780 - val_loss: 0.1208
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9722 - loss: 0.1158 - val_accuracy: 0.9780 - val_loss: 0.1196
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9755 - loss: 0.1250 - val_accuracy: 0.9780 - val_loss: 0.1185
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9675 - loss: 0.1247 - val_accuracy: 0.9890 - val_loss: 0.1173
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9686 - loss: 0.1307 - val_accuracy: 0.9890 - val_loss: 0.1162
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9617 - loss: 0.1205 - val_accuracy: 0.9890 - val_loss: 0.1151
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9727 - loss: 0.1172 - val_accuracy: 0.9890 - val_loss: 0.1143
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9589 - loss: 0.1299 - val_accuracy: 0.9890 - val_loss: 0.1132
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9626 - loss: 0.1343 - val_accuracy: 0.9890 - val_loss: 0.1123
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9574 - loss: 0.1342 - val_accuracy: 0.9890 - val_loss: 0.1114
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9597 - loss: 0.1234 - val_accuracy: 0.9890 - val_loss: 0.1104
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9686 - loss: 0.1085 - val_accuracy: 0.9890 - val_loss: 0.1094
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9638 - loss: 0.1105 - val_accuracy: 0.9890 - val_loss: 0.1085
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9720 - loss: 0.1105 - val_accuracy: 0.9890 - val_loss: 0.1077
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9757 - loss: 0.1173 - val_accuracy: 0.9890 - val_loss: 0.1068
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9667 - loss: 0.1472 - val_accuracy: 0.9890 - val_loss: 0.1061
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9660 - loss: 0.1372 - val_accuracy: 0.9890 - val_loss: 0.1051
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9687 - loss: 0.1274 - val_accuracy: 0.9890 - val_loss: 0.1043
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9658 - loss: 0.1101 - val_accuracy: 0.9890 - val_loss: 0.1036
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9740 - loss: 0.0980 - val_accuracy: 0.9890 - val_loss: 0.1029
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9638 - loss: 0.1142 - val_accuracy: 0.9890 - val_loss: 0.1021
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9819 - loss: 0.0904 - val_accuracy: 0.9890 - val_loss: 0.1014
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9749 - loss: 0.1169 - val_accuracy: 0.9890 - val_loss: 0.1007
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9706 - loss: 0.1019 - val_accuracy: 0.9890 - val_loss: 0.1000
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9671 - loss: 0.1303 - val_accuracy: 0.9890 - val_loss: 0.0993
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9737 - loss: 0.1024 - val_accuracy: 0.9890 - val_loss: 0.0986
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9758 - loss: 0.0906 - val_accuracy: 0.9890 - val_loss: 0.0979
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9771 - loss: 0.1014 - val_accuracy: 0.9890 - val_loss: 0.0974
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9769 - loss: 0.1170 - val_accuracy: 0.9890 - val_loss: 0.0968
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9626 - loss: 0.1103 - val_accuracy: 0.9890 - val_loss: 0.0962
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9770 - loss: 0.1039 - val_accuracy: 0.9890 - val_loss: 0.0956
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9717 - loss: 0.1030 - val_accuracy: 0.9890 - val_loss: 0.0950
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9674 - loss: 0.1067 - val_accuracy: 0.9890 - val_loss: 0.0945
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9587 - loss: 0.1326 - val_accuracy: 0.9890 - val_loss: 0.0940
# Final Training Loss:     0.1036
# Final Training Accuracy: 0.9698

# %%
# Set a1c to the final training accuracy (at epoch 100)
# You MUST use an expression here, not a constant from inspecting the results

a1c = history.history['accuracy'][-1]             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way

print(f'a1c = {a1c:.4f}')
# Out:
# a1c = 0.9698

# %% [markdown]
# ### Part D: Testing
#
# - Calculate the testing loss and accuracy and answer the graded question.
# - Print out both with appropriate labels
# - Answer the graded question

# %%
# Your code here
test_loss, test_accuracy = model_baseline.evaluate(X_test_scaled, y_test)

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9502 - loss: 0.1511
# Test Loss: 0.1425
# Test Accuracy: 0.9561

# %%
# Set a1d to the final testing accuracy
# Use the appropriate variable; do not insert a constant from inspection of the results

a1d = test_accuracy             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way

print(f'a1d = {a1d:.4f}')
# Out:
# a1d = 0.9561

# %% [markdown]
# ## Problem Two: Explore alternate network designs
#
# For the remaining problems, you will experiment with several different network designs.
#
# For Problem Two, redo the work you did in Parts C and D of Problem One, but with a network with a single hidden layer of 16 neurons, using the sigmoid activation function, which
# will have the following summary chart (the layer name may be different than shown here):
#
# ![Screenshot 2025-05-14 at 9.53.39 PM.png](attachment:289e078f-0957-43a2-b756-1b11145abf9a.png)
#
#
# Then answer the graded questions.

# %%
# Your code here, add additional cells if you wish
# 1️⃣ Define the network
model_hidden = keras.Sequential([
    keras.layers.Input(shape=(X_train_scaled.shape[1],)),  # input layer
    keras.layers.Dense(16, activation='sigmoid'),          # hidden layer with 16 neurons
    keras.layers.Dense(1, activation='sigmoid')           # output layer
])

# 2️⃣ Compile the model
model_hidden.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# 3️⃣ Calculate class weights
classes = np.unique(y_train)
class_weights_array = class_weight.compute_class_weight('balanced', classes=classes, y=y_train)
class_weights = {i: class_weights_array[i] for i in range(len(classes))}

# 4️⃣ Train the model
history_hidden = model_hidden.fit(
    X_train_scaled,
    y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    class_weight=class_weights,
    verbose=1
)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.7694 - loss: 0.5962 - val_accuracy: 0.8681 - val_loss: 0.5682
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8828 - loss: 0.5448 - val_accuracy: 0.8901 - val_loss: 0.5120
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9182 - loss: 0.4894 - val_accuracy: 0.9121 - val_loss: 0.4651
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9466 - loss: 0.4458 - val_accuracy: 0.9231 - val_loss: 0.4262
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9483 - loss: 0.3926 - val_accuracy: 0.9451 - val_loss: 0.3933
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9473 - loss: 0.3710 - val_accuracy: 0.9451 - val_loss: 0.3660
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9431 - loss: 0.3476 - val_accuracy: 0.9451 - val_loss: 0.3416
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9372 - loss: 0.3301 - val_accuracy: 0.9560 - val_loss: 0.3202
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9237 - loss: 0.3195 - val_accuracy: 0.9670 - val_loss: 0.3019
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9505 - loss: 0.2786 - val_accuracy: 0.9670 - val_loss: 0.2849
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9574 - loss: 0.2701 - val_accuracy: 0.9670 - val_loss: 0.2696
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9377 - loss: 0.2661 - val_accuracy: 0.9670 - val_loss: 0.2562
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9517 - loss: 0.2466 - val_accuracy: 0.9670 - val_loss: 0.2442
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9499 - loss: 0.2407 - val_accuracy: 0.9670 - val_loss: 0.2327
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9647 - loss: 0.2247 - val_accuracy: 0.9670 - val_loss: 0.2228
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9731 - loss: 0.2182 - val_accuracy: 0.9670 - val_loss: 0.2135
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9666 - loss: 0.1856 - val_accuracy: 0.9670 - val_loss: 0.2043
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9608 - loss: 0.2082 - val_accuracy: 0.9670 - val_loss: 0.1959
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9671 - loss: 0.1806 - val_accuracy: 0.9670 - val_loss: 0.1886
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9617 - loss: 0.1969 - val_accuracy: 0.9670 - val_loss: 0.1815
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9589 - loss: 0.1750 - val_accuracy: 0.9670 - val_loss: 0.1747
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9608 - loss: 0.1743 - val_accuracy: 0.9670 - val_loss: 0.1682
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9676 - loss: 0.1584 - val_accuracy: 0.9670 - val_loss: 0.1622
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9677 - loss: 0.1493 - val_accuracy: 0.9670 - val_loss: 0.1571
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9652 - loss: 0.1567 - val_accuracy: 0.9670 - val_loss: 0.1522
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9645 - loss: 0.1520 - val_accuracy: 0.9670 - val_loss: 0.1472
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9622 - loss: 0.1643 - val_accuracy: 0.9670 - val_loss: 0.1428
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9671 - loss: 0.1593 - val_accuracy: 0.9670 - val_loss: 0.1386
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9691 - loss: 0.1355 - val_accuracy: 0.9670 - val_loss: 0.1343
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9699 - loss: 0.1173 - val_accuracy: 0.9780 - val_loss: 0.1307
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9676 - loss: 0.1375 - val_accuracy: 0.9780 - val_loss: 0.1272
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9725 - loss: 0.1348 - val_accuracy: 0.9780 - val_loss: 0.1241
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9770 - loss: 0.1044 - val_accuracy: 0.9780 - val_loss: 0.1208
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9641 - loss: 0.1486 - val_accuracy: 0.9780 - val_loss: 0.1184
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9739 - loss: 0.1233 - val_accuracy: 0.9780 - val_loss: 0.1157
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9740 - loss: 0.1160 - val_accuracy: 0.9780 - val_loss: 0.1128
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9790 - loss: 0.1289 - val_accuracy: 0.9780 - val_loss: 0.1101
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9833 - loss: 0.1114 - val_accuracy: 0.9780 - val_loss: 0.1080
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9826 - loss: 0.1141 - val_accuracy: 0.9780 - val_loss: 0.1058
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9747 - loss: 0.1133 - val_accuracy: 0.9780 - val_loss: 0.1037
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9804 - loss: 0.0931 - val_accuracy: 0.9780 - val_loss: 0.1014
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9729 - loss: 0.1185 - val_accuracy: 0.9780 - val_loss: 0.0995
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9733 - loss: 0.1171 - val_accuracy: 0.9890 - val_loss: 0.0976
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9797 - loss: 0.0968 - val_accuracy: 0.9890 - val_loss: 0.0956
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9838 - loss: 0.0925 - val_accuracy: 0.9890 - val_loss: 0.0941
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9869 - loss: 0.0902 - val_accuracy: 0.9890 - val_loss: 0.0928
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9694 - loss: 0.1083 - val_accuracy: 0.9890 - val_loss: 0.0913
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9739 - loss: 0.1315 - val_accuracy: 0.9890 - val_loss: 0.0901
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9819 - loss: 0.0774 - val_accuracy: 0.9890 - val_loss: 0.0885
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9899 - loss: 0.0775 - val_accuracy: 0.9890 - val_loss: 0.0870
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9830 - loss: 0.0942 - val_accuracy: 0.9890 - val_loss: 0.0858
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9812 - loss: 0.0821 - val_accuracy: 0.9890 - val_loss: 0.0845
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9824 - loss: 0.0860 - val_accuracy: 0.9890 - val_loss: 0.0833
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9675 - loss: 0.1068 - val_accuracy: 0.9890 - val_loss: 0.0823
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9769 - loss: 0.1011 - val_accuracy: 0.9890 - val_loss: 0.0813
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9826 - loss: 0.0767 - val_accuracy: 0.9890 - val_loss: 0.0803
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9785 - loss: 0.0882 - val_accuracy: 0.9890 - val_loss: 0.0792
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9792 - loss: 0.0789 - val_accuracy: 0.9890 - val_loss: 0.0783
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9706 - loss: 0.1070 - val_accuracy: 0.9890 - val_loss: 0.0775
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9813 - loss: 0.0778 - val_accuracy: 0.9890 - val_loss: 0.0767
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9781 - loss: 0.0847 - val_accuracy: 0.9890 - val_loss: 0.0760
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9787 - loss: 0.0900 - val_accuracy: 0.9890 - val_loss: 0.0752
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9826 - loss: 0.0851 - val_accuracy: 0.9890 - val_loss: 0.0745
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9739 - loss: 0.1139 - val_accuracy: 0.9890 - val_loss: 0.0735
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9726 - loss: 0.0869 - val_accuracy: 0.9890 - val_loss: 0.0728
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9762 - loss: 0.0829 - val_accuracy: 0.9890 - val_loss: 0.0718
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9710 - loss: 0.0953 - val_accuracy: 0.9890 - val_loss: 0.0711
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9797 - loss: 0.0745 - val_accuracy: 0.9890 - val_loss: 0.0704
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9807 - loss: 0.0779 - val_accuracy: 0.9890 - val_loss: 0.0701
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9730 - loss: 0.0779 - val_accuracy: 0.9890 - val_loss: 0.0695
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9841 - loss: 0.0729 - val_accuracy: 0.9890 - val_loss: 0.0690
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9771 - loss: 0.0759 - val_accuracy: 0.9890 - val_loss: 0.0685
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9812 - loss: 0.0834 - val_accuracy: 0.9890 - val_loss: 0.0687
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9827 - loss: 0.0768 - val_accuracy: 0.9890 - val_loss: 0.0681
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9806 - loss: 0.0606 - val_accuracy: 0.9890 - val_loss: 0.0674
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9792 - loss: 0.0692 - val_accuracy: 0.9890 - val_loss: 0.0669
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9641 - loss: 0.1113 - val_accuracy: 0.9890 - val_loss: 0.0663
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9848 - loss: 0.0650 - val_accuracy: 0.9890 - val_loss: 0.0659
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9773 - loss: 0.0631 - val_accuracy: 0.9890 - val_loss: 0.0654
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9854 - loss: 0.0575 - val_accuracy: 0.9890 - val_loss: 0.0650
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9824 - loss: 0.0691 - val_accuracy: 0.9890 - val_loss: 0.0647
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9681 - loss: 0.0897 - val_accuracy: 0.9890 - val_loss: 0.0642
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9718 - loss: 0.0939 - val_accuracy: 0.9890 - val_loss: 0.0641
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9764 - loss: 0.0920 - val_accuracy: 0.9890 - val_loss: 0.0637
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9770 - loss: 0.0929 - val_accuracy: 0.9890 - val_loss: 0.0634
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9787 - loss: 0.0639 - val_accuracy: 0.9890 - val_loss: 0.0629
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9731 - loss: 0.0790 - val_accuracy: 0.9890 - val_loss: 0.0628
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9810 - loss: 0.0742 - val_accuracy: 0.9890 - val_loss: 0.0623
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9826 - loss: 0.0613 - val_accuracy: 0.9890 - val_loss: 0.0620
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9688 - loss: 0.0989 - val_accuracy: 0.9890 - val_loss: 0.0617
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9823 - loss: 0.0573 - val_accuracy: 0.9890 - val_loss: 0.0613
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9847 - loss: 0.0757 - val_accuracy: 0.9890 - val_loss: 0.0611
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9848 - loss: 0.0571 - val_accuracy: 0.9890 - val_loss: 0.0606
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9885 - loss: 0.0559 - val_accuracy: 0.9890 - val_loss: 0.0601
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9893 - loss: 0.0527 - val_accuracy: 0.9890 - val_loss: 0.0597
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9707 - loss: 0.1023 - val_accuracy: 0.9890 - val_loss: 0.0599
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9834 - loss: 0.0761 - val_accuracy: 0.9890 - val_loss: 0.0596
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9787 - loss: 0.0607 - val_accuracy: 0.9890 - val_loss: 0.0592
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9812 - loss: 0.0780 - val_accuracy: 0.9890 - val_loss: 0.0592
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9857 - loss: 0.0662 - val_accuracy: 0.9890 - val_loss: 0.0590

# %%
test_loss_hidden, test_accuracy_hidden = model_hidden.evaluate(X_test_scaled, y_test)

print(f"Test Loss: {test_loss_hidden:.4f}")
print(f"Test Accuracy: {test_accuracy_hidden:.4f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9383 - loss: 0.1212
# Test Loss: 0.1109
# Test Accuracy: 0.9474

# %%
# Set a2a to the final training accuracy
# Use the appropriate variable or expression; do not insert a constant from inspection of the results

a2a = history_hidden.history['accuracy'][-1]            # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way

print(f'a2a = {a2a:.4f}')
# Out:
# a2a = 0.9808

# %%
# Set a2b to the final testing accuracy
# Use the appropriate variable; do not insert a constant from inspection of the results

a2b = test_accuracy_hidden             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way

print(f'a2b = {a2b:.4f}')
# Out:
# a2b = 0.9474

# %% [markdown]
# ## Problem Three: Explore alternate network designs
#
#
# For Problem Three, redo the work you did in Parts C and D of Problem One, but with a network with a  hidden layer of 64 neurons,
# using the sigmoid activation function, which
# will have the following summary chart:
#
# ![Screenshot 2025-05-14 at 9.53.30 PM.png](attachment:1d505d45-e05e-4c0d-b125-70c1697ef5ba.png)
#
#
# Then answer the graded questions.

# %%
# Your code here, add additional cells if you wish
# 1️⃣ Define the network
model_hidden_64 = keras.Sequential([
    keras.layers.Input(shape=(X_train_scaled.shape[1],)),  # input layer
    keras.layers.Dense(64, activation='sigmoid'),          # hidden layer with 64 neurons
    keras.layers.Dense(1, activation='sigmoid')           # output layer
])

# 2️⃣ Compile the model
model_hidden_64.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# 3️⃣ Compute class weights
classes = np.unique(y_train)
class_weights_array = class_weight.compute_class_weight('balanced', classes=classes, y=y_train)
class_weights = {i: class_weights_array[i] for i in range(len(classes))}

# 4️⃣ Train the model
history_hidden_64 = model_hidden_64.fit(
    X_train_scaled,
    y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    class_weight=class_weights,
    verbose=1
)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7987 - loss: 0.6212 - val_accuracy: 0.8901 - val_loss: 0.5294
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9393 - loss: 0.4810 - val_accuracy: 0.9231 - val_loss: 0.4327
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9485 - loss: 0.3777 - val_accuracy: 0.9341 - val_loss: 0.3643
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9232 - loss: 0.3435 - val_accuracy: 0.9341 - val_loss: 0.3128
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9540 - loss: 0.2770 - val_accuracy: 0.9451 - val_loss: 0.2739
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9336 - loss: 0.2488 - val_accuracy: 0.9560 - val_loss: 0.2407
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9456 - loss: 0.2282 - val_accuracy: 0.9560 - val_loss: 0.2182
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9600 - loss: 0.1916 - val_accuracy: 0.9560 - val_loss: 0.1998
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9649 - loss: 0.1853 - val_accuracy: 0.9560 - val_loss: 0.1854
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9731 - loss: 0.1732 - val_accuracy: 0.9670 - val_loss: 0.1729
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9695 - loss: 0.1584 - val_accuracy: 0.9670 - val_loss: 0.1589
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9820 - loss: 0.1569 - val_accuracy: 0.9670 - val_loss: 0.1503
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9668 - loss: 0.1463 - val_accuracy: 0.9780 - val_loss: 0.1413
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9631 - loss: 0.1508 - val_accuracy: 0.9780 - val_loss: 0.1338
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9800 - loss: 0.1276 - val_accuracy: 0.9780 - val_loss: 0.1261
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9811 - loss: 0.1276 - val_accuracy: 0.9780 - val_loss: 0.1202
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9794 - loss: 0.1087 - val_accuracy: 0.9890 - val_loss: 0.1144
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9805 - loss: 0.1013 - val_accuracy: 0.9890 - val_loss: 0.1102
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9697 - loss: 0.1373 - val_accuracy: 0.9890 - val_loss: 0.1068
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9885 - loss: 0.0859 - val_accuracy: 0.9890 - val_loss: 0.1028
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9715 - loss: 0.1123 - val_accuracy: 0.9890 - val_loss: 0.0995
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9809 - loss: 0.0950 - val_accuracy: 0.9890 - val_loss: 0.0973
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9849 - loss: 0.0832 - val_accuracy: 0.9890 - val_loss: 0.0936
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9760 - loss: 0.1147 - val_accuracy: 0.9890 - val_loss: 0.0928
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9728 - loss: 0.1056 - val_accuracy: 0.9890 - val_loss: 0.0897
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9694 - loss: 0.0953 - val_accuracy: 0.9890 - val_loss: 0.0874
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9765 - loss: 0.1023 - val_accuracy: 0.9890 - val_loss: 0.0859
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9758 - loss: 0.1051 - val_accuracy: 0.9890 - val_loss: 0.0842
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9765 - loss: 0.0890 - val_accuracy: 0.9890 - val_loss: 0.0819
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9781 - loss: 0.0853 - val_accuracy: 0.9890 - val_loss: 0.0807
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9812 - loss: 0.0676 - val_accuracy: 0.9890 - val_loss: 0.0795
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9803 - loss: 0.0897 - val_accuracy: 0.9890 - val_loss: 0.0782
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9781 - loss: 0.0772 - val_accuracy: 0.9890 - val_loss: 0.0767
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9819 - loss: 0.0827 - val_accuracy: 0.9890 - val_loss: 0.0757
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9737 - loss: 0.0917 - val_accuracy: 0.9890 - val_loss: 0.0741
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9831 - loss: 0.0768 - val_accuracy: 0.9890 - val_loss: 0.0734
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9840 - loss: 0.0796 - val_accuracy: 0.9890 - val_loss: 0.0727
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9845 - loss: 0.0672 - val_accuracy: 0.9890 - val_loss: 0.0717
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9797 - loss: 0.0651 - val_accuracy: 0.9890 - val_loss: 0.0699
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9814 - loss: 0.0626 - val_accuracy: 0.9890 - val_loss: 0.0702
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9834 - loss: 0.0743 - val_accuracy: 0.9890 - val_loss: 0.0701
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9773 - loss: 0.0884 - val_accuracy: 0.9890 - val_loss: 0.0693
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9857 - loss: 0.0630 - val_accuracy: 0.9890 - val_loss: 0.0677
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9859 - loss: 0.0619 - val_accuracy: 0.9890 - val_loss: 0.0670
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9664 - loss: 0.1024 - val_accuracy: 0.9890 - val_loss: 0.0688
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9689 - loss: 0.0737 - val_accuracy: 0.9890 - val_loss: 0.0674
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9676 - loss: 0.0945 - val_accuracy: 0.9890 - val_loss: 0.0667
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9846 - loss: 0.0568 - val_accuracy: 0.9890 - val_loss: 0.0657
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9928 - loss: 0.0500 - val_accuracy: 0.9890 - val_loss: 0.0650
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9824 - loss: 0.0633 - val_accuracy: 0.9890 - val_loss: 0.0646
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9731 - loss: 0.0991 - val_accuracy: 0.9890 - val_loss: 0.0648
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9807 - loss: 0.0612 - val_accuracy: 0.9890 - val_loss: 0.0641
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9821 - loss: 0.0605 - val_accuracy: 0.9890 - val_loss: 0.0636
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9791 - loss: 0.0647 - val_accuracy: 0.9890 - val_loss: 0.0628
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9773 - loss: 0.0607 - val_accuracy: 0.9780 - val_loss: 0.0624
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9768 - loss: 0.0733 - val_accuracy: 0.9780 - val_loss: 0.0623
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9876 - loss: 0.0560 - val_accuracy: 0.9780 - val_loss: 0.0620
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9712 - loss: 0.0695 - val_accuracy: 0.9780 - val_loss: 0.0614
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9866 - loss: 0.0671 - val_accuracy: 0.9780 - val_loss: 0.0615
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9878 - loss: 0.0629 - val_accuracy: 0.9780 - val_loss: 0.0607
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9918 - loss: 0.0425 - val_accuracy: 0.9780 - val_loss: 0.0606
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9848 - loss: 0.0693 - val_accuracy: 0.9780 - val_loss: 0.0607
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9811 - loss: 0.0663 - val_accuracy: 0.9780 - val_loss: 0.0605
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9874 - loss: 0.0669 - val_accuracy: 0.9780 - val_loss: 0.0600
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9882 - loss: 0.0579 - val_accuracy: 0.9780 - val_loss: 0.0594
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0582 - val_accuracy: 0.9780 - val_loss: 0.0591
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9906 - loss: 0.0435 - val_accuracy: 0.9780 - val_loss: 0.0594
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9847 - loss: 0.0496 - val_accuracy: 0.9780 - val_loss: 0.0604
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9806 - loss: 0.0651 - val_accuracy: 0.9780 - val_loss: 0.0613
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9821 - loss: 0.0508 - val_accuracy: 0.9780 - val_loss: 0.0611
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9833 - loss: 0.0525 - val_accuracy: 0.9780 - val_loss: 0.0600
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9830 - loss: 0.0475 - val_accuracy: 0.9780 - val_loss: 0.0601
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9886 - loss: 0.0513 - val_accuracy: 0.9780 - val_loss: 0.0599
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9813 - loss: 0.0769 - val_accuracy: 0.9780 - val_loss: 0.0608
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9862 - loss: 0.0466 - val_accuracy: 0.9780 - val_loss: 0.0600
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9822 - loss: 0.0543 - val_accuracy: 0.9780 - val_loss: 0.0591
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9805 - loss: 0.0542 - val_accuracy: 0.9780 - val_loss: 0.0587
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0611 - val_accuracy: 0.9780 - val_loss: 0.0588
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9857 - loss: 0.0481 - val_accuracy: 0.9780 - val_loss: 0.0582
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9880 - loss: 0.0501 - val_accuracy: 0.9780 - val_loss: 0.0588
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9865 - loss: 0.0544 - val_accuracy: 0.9780 - val_loss: 0.0586
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9742 - loss: 0.0670 - val_accuracy: 0.9780 - val_loss: 0.0580
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9733 - loss: 0.0919 - val_accuracy: 0.9780 - val_loss: 0.0586
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9918 - loss: 0.0457 - val_accuracy: 0.9780 - val_loss: 0.0579
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9890 - loss: 0.0431 - val_accuracy: 0.9780 - val_loss: 0.0580
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9766 - loss: 0.0767 - val_accuracy: 0.9780 - val_loss: 0.0585
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9783 - loss: 0.0825 - val_accuracy: 0.9670 - val_loss: 0.0586
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9838 - loss: 0.0659 - val_accuracy: 0.9670 - val_loss: 0.0585
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9810 - loss: 0.0732 - val_accuracy: 0.9780 - val_loss: 0.0582
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9805 - loss: 0.0498 - val_accuracy: 0.9780 - val_loss: 0.0572
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9826 - loss: 0.0550 - val_accuracy: 0.9670 - val_loss: 0.0590
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9840 - loss: 0.0477 - val_accuracy: 0.9670 - val_loss: 0.0595
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9675 - loss: 0.0886 - val_accuracy: 0.9670 - val_loss: 0.0605
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9860 - loss: 0.0479 - val_accuracy: 0.9670 - val_loss: 0.0597
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9884 - loss: 0.0398 - val_accuracy: 0.9780 - val_loss: 0.0582
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9815 - loss: 0.0585 - val_accuracy: 0.9780 - val_loss: 0.0576
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9871 - loss: 0.0468 - val_accuracy: 0.9780 - val_loss: 0.0575
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9857 - loss: 0.0454 - val_accuracy: 0.9670 - val_loss: 0.0573
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9889 - loss: 0.0376 - val_accuracy: 0.9780 - val_loss: 0.0566
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9838 - loss: 0.0712 - val_accuracy: 0.9670 - val_loss: 0.0578

# %%
test_loss_64, test_accuracy_64 = model_hidden_64.evaluate(X_test_scaled, y_test)

print(f"Test Loss: {test_loss_64:.4f}")
print(f"Test Accuracy: {test_accuracy_64:.4f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9383 - loss: 0.1104
# Test Loss: 0.1011
# Test Accuracy: 0.9474

# %%
# Set a3a to the final training accuracy
# Use the appropriate variable or expression; do not insert a constant from inspection of the results

a3a = history_hidden_64.history['accuracy'][-1]             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way

print(f'a3a = {a3a:.4f}')
# Out:
# a3a = 0.9835

# %%
# Set a3b to the final testing accuracy
# Use the appropriate variable; do not insert a constant from inspection of the results

a3b = test_accuracy_64            # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way

print(f'a3b = {a3b:.4f}')
# Out:
# a3b = 0.9474

# %% [markdown]
# ## Problem Four: Explore alternate network designs
#
#
# For Problem Four, redo the work you did in Parts C and D of Problem One, but with a network with  a hidden layer of 256 neurons, using the sigmoid activation function, which
# will have the following summary chart:
#
# ![Screenshot 2025-05-14 at 9.53.20 PM.png](attachment:464f1603-0ac4-4ca2-8f3e-affe3ee25b5a.png)
#
#
# Then answer the graded questions.

# %%
# Your code here, add additional cells if you wish

# 1️⃣ Define the network
model_hidden_256 = keras.Sequential([
    keras.layers.Input(shape=(X_train_scaled.shape[1],)),  # input layer
    keras.layers.Dense(256, activation='sigmoid'),          # hidden layer with 256 neurons
    keras.layers.Dense(1, activation='sigmoid')           # output layer
])

# 2️⃣ Compile the model
model_hidden_256.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# 3️⃣ Compute class weights
classes = np.unique(y_train)
class_weights_array = class_weight.compute_class_weight('balanced', classes=classes, y=y_train)
class_weights = {i: class_weights_array[i] for i in range(len(classes))}

# 4️⃣ Train the model
history_hidden_256 = model_hidden_256.fit(
    X_train_scaled,
    y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    class_weight=class_weights,
    verbose=1
)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7228 - loss: 0.6180 - val_accuracy: 0.9341 - val_loss: 0.4016
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9553 - loss: 0.3427 - val_accuracy: 0.9341 - val_loss: 0.2757
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9242 - loss: 0.2761 - val_accuracy: 0.9670 - val_loss: 0.2255
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9552 - loss: 0.2026 - val_accuracy: 0.9560 - val_loss: 0.1802
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9486 - loss: 0.1871 - val_accuracy: 0.9670 - val_loss: 0.1678
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9619 - loss: 0.1716 - val_accuracy: 0.9670 - val_loss: 0.1391
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9776 - loss: 0.1144 - val_accuracy: 0.9670 - val_loss: 0.1251
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9825 - loss: 0.1279 - val_accuracy: 0.9670 - val_loss: 0.1259
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9794 - loss: 0.1178 - val_accuracy: 0.9780 - val_loss: 0.1133
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9861 - loss: 0.1082 - val_accuracy: 0.9780 - val_loss: 0.1050
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9800 - loss: 0.1077 - val_accuracy: 0.9890 - val_loss: 0.0973
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9767 - loss: 0.1012 - val_accuracy: 0.9780 - val_loss: 0.0998
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9844 - loss: 0.0924 - val_accuracy: 0.9780 - val_loss: 0.0943
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9806 - loss: 0.0932 - val_accuracy: 0.9890 - val_loss: 0.0872
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9772 - loss: 0.0818 - val_accuracy: 0.9890 - val_loss: 0.0837
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9670 - loss: 0.1121 - val_accuracy: 0.9890 - val_loss: 0.0853
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9658 - loss: 0.1031 - val_accuracy: 0.9890 - val_loss: 0.0821
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9695 - loss: 0.1002 - val_accuracy: 0.9890 - val_loss: 0.0757
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9676 - loss: 0.0854 - val_accuracy: 0.9890 - val_loss: 0.0772
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9810 - loss: 0.0791 - val_accuracy: 0.9890 - val_loss: 0.0763
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9735 - loss: 0.0750 - val_accuracy: 0.9890 - val_loss: 0.0718
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9840 - loss: 0.0613 - val_accuracy: 0.9890 - val_loss: 0.0700
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9799 - loss: 0.0606 - val_accuracy: 0.9890 - val_loss: 0.0717
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9572 - loss: 0.1119 - val_accuracy: 0.9890 - val_loss: 0.0705
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9732 - loss: 0.0720 - val_accuracy: 0.9890 - val_loss: 0.0670
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9810 - loss: 0.0598 - val_accuracy: 0.9890 - val_loss: 0.0652
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9786 - loss: 0.0770 - val_accuracy: 0.9890 - val_loss: 0.0681
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9806 - loss: 0.0745 - val_accuracy: 0.9890 - val_loss: 0.0651
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9811 - loss: 0.0574 - val_accuracy: 0.9890 - val_loss: 0.0621
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9841 - loss: 0.0667 - val_accuracy: 0.9890 - val_loss: 0.0611
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9705 - loss: 0.0820 - val_accuracy: 0.9890 - val_loss: 0.0662
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9681 - loss: 0.0768 - val_accuracy: 0.9890 - val_loss: 0.0640
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9772 - loss: 0.0585 - val_accuracy: 0.9890 - val_loss: 0.0636
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9756 - loss: 0.0562 - val_accuracy: 0.9890 - val_loss: 0.0616
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9731 - loss: 0.0790 - val_accuracy: 0.9890 - val_loss: 0.0653
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9817 - loss: 0.0520 - val_accuracy: 0.9890 - val_loss: 0.0610
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9766 - loss: 0.0828 - val_accuracy: 0.9890 - val_loss: 0.0624
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9721 - loss: 0.0713 - val_accuracy: 0.9890 - val_loss: 0.0600
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9875 - loss: 0.0562 - val_accuracy: 0.9890 - val_loss: 0.0586
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9874 - loss: 0.0570 - val_accuracy: 0.9890 - val_loss: 0.0605
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9802 - loss: 0.0569 - val_accuracy: 0.9780 - val_loss: 0.0609
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9852 - loss: 0.0573 - val_accuracy: 0.9780 - val_loss: 0.0591
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9855 - loss: 0.0541 - val_accuracy: 0.9890 - val_loss: 0.0572
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9825 - loss: 0.0555 - val_accuracy: 0.9780 - val_loss: 0.0600
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9822 - loss: 0.0551 - val_accuracy: 0.9670 - val_loss: 0.0630
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9808 - loss: 0.0731 - val_accuracy: 0.9670 - val_loss: 0.0643
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9892 - loss: 0.0497 - val_accuracy: 0.9780 - val_loss: 0.0553
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9761 - loss: 0.0720 - val_accuracy: 0.9780 - val_loss: 0.0563
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9793 - loss: 0.0729 - val_accuracy: 0.9780 - val_loss: 0.0589
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9788 - loss: 0.0594 - val_accuracy: 0.9780 - val_loss: 0.0573
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9845 - loss: 0.0531 - val_accuracy: 0.9780 - val_loss: 0.0599
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9825 - loss: 0.0458 - val_accuracy: 0.9670 - val_loss: 0.0608
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9895 - loss: 0.0408 - val_accuracy: 0.9670 - val_loss: 0.0625
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9761 - loss: 0.0571 - val_accuracy: 0.9780 - val_loss: 0.0585
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9934 - loss: 0.0385 - val_accuracy: 0.9780 - val_loss: 0.0576
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9899 - loss: 0.0428 - val_accuracy: 0.9670 - val_loss: 0.0645
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9871 - loss: 0.0374 - val_accuracy: 0.9560 - val_loss: 0.0741
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9780 - loss: 0.0678 - val_accuracy: 0.9780 - val_loss: 0.0620
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9789 - loss: 0.0731 - val_accuracy: 0.9780 - val_loss: 0.0628
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9683 - loss: 0.0880 - val_accuracy: 0.9780 - val_loss: 0.0608
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9838 - loss: 0.0625 - val_accuracy: 0.9780 - val_loss: 0.0598
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9806 - loss: 0.0796 - val_accuracy: 0.9780 - val_loss: 0.0595
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9914 - loss: 0.0545 - val_accuracy: 0.9780 - val_loss: 0.0579
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9839 - loss: 0.0567 - val_accuracy: 0.9780 - val_loss: 0.0599
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9829 - loss: 0.0615 - val_accuracy: 0.9780 - val_loss: 0.0610
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9888 - loss: 0.0384 - val_accuracy: 0.9670 - val_loss: 0.0602
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9833 - loss: 0.0471 - val_accuracy: 0.9670 - val_loss: 0.0593
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9825 - loss: 0.0804 - val_accuracy: 0.9670 - val_loss: 0.0614
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9857 - loss: 0.0616 - val_accuracy: 0.9670 - val_loss: 0.0596
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9874 - loss: 0.0540 - val_accuracy: 0.9780 - val_loss: 0.0579
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9839 - loss: 0.0543 - val_accuracy: 0.9780 - val_loss: 0.0570
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9796 - loss: 0.0692 - val_accuracy: 0.9780 - val_loss: 0.0577
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9922 - loss: 0.0356 - val_accuracy: 0.9670 - val_loss: 0.0583
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9778 - loss: 0.0708 - val_accuracy: 0.9670 - val_loss: 0.0596
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9856 - loss: 0.0469 - val_accuracy: 0.9670 - val_loss: 0.0652
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9730 - loss: 0.0757 - val_accuracy: 0.9670 - val_loss: 0.0619
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9759 - loss: 0.0757 - val_accuracy: 0.9780 - val_loss: 0.0578
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9788 - loss: 0.0742 - val_accuracy: 0.9780 - val_loss: 0.0574
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9862 - loss: 0.0647 - val_accuracy: 0.9780 - val_loss: 0.0565
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9857 - loss: 0.0338 - val_accuracy: 0.9780 - val_loss: 0.0574
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9887 - loss: 0.0494 - val_accuracy: 0.9670 - val_loss: 0.0637
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9904 - loss: 0.0411 - val_accuracy: 0.9670 - val_loss: 0.0582
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9895 - loss: 0.0468 - val_accuracy: 0.9780 - val_loss: 0.0567
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9888 - loss: 0.0571 - val_accuracy: 0.9780 - val_loss: 0.0584
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9918 - loss: 0.0380 - val_accuracy: 0.9780 - val_loss: 0.0585
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9871 - loss: 0.0518 - val_accuracy: 0.9780 - val_loss: 0.0582
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9844 - loss: 0.0575 - val_accuracy: 0.9670 - val_loss: 0.0604
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9892 - loss: 0.0347 - val_accuracy: 0.9670 - val_loss: 0.0591
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9883 - loss: 0.0406 - val_accuracy: 0.9670 - val_loss: 0.0640
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9830 - loss: 0.0597 - val_accuracy: 0.9670 - val_loss: 0.0713
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9820 - loss: 0.0580 - val_accuracy: 0.9670 - val_loss: 0.0662
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9855 - loss: 0.0384 - val_accuracy: 0.9780 - val_loss: 0.0622
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9850 - loss: 0.0427 - val_accuracy: 0.9670 - val_loss: 0.0650
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9758 - loss: 0.0505 - val_accuracy: 0.9670 - val_loss: 0.0640
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0499 - val_accuracy: 0.9670 - val_loss: 0.0652
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9836 - loss: 0.0489 - val_accuracy: 0.9670 - val_loss: 0.0605
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9810 - loss: 0.0489 - val_accuracy: 0.9670 - val_loss: 0.0612
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9877 - loss: 0.0405 - val_accuracy: 0.9670 - val_loss: 0.0605
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0330 - val_accuracy: 0.9780 - val_loss: 0.0577
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9825 - loss: 0.0574 - val_accuracy: 0.9670 - val_loss: 0.0721

# %%
test_loss_256, test_accuracy_256 = model_hidden_256.evaluate(X_test_scaled, y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9383 - loss: 0.1256

# %%
# Set a4a to the final training accuracy
# Use the appropriate variable or expression; do not insert a constant from inspection of the results

a4a = history_hidden_256.history['accuracy'][-1]            # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way

print(f'a4a = {a4a:.4f}')
# Out:
# a4a = 0.9808

# %%
# Set a4b to the final testing accuracy
# Use the appropriate variable; do not insert a constant from inspection of the results

a4b = test_accuracy_256             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way

print(f'a4b = {a4b:.4f}')
# Out:
# a4b = 0.9474

# %% [markdown]
# ## Problem Five: Explore alternate network designs
#
#
# For Problem Five, redo the work you did in Parts C and D of Problem One, but with a network with two hidden layers of 64  and 32 neurons, using the sigmoid activation function for all layers, which
# will have the following summary chart:
#
# ![Screenshot 2025-05-14 at 9.52.42 PM.png](attachment:b6094f80-be1d-4ade-be21-44e24aab768f.png)
#
# Then answer the graded questions.

# %%
# Your code here, add additional cells if you wish

# %%
# Your code here, add additional cells if you wish

# 1️⃣ Define the network
model_hidden_64_32 = keras.Sequential([
    keras.layers.Input(shape=(X_train_scaled.shape[1],)),  # input layer
    keras.layers.Dense(64, activation='sigmoid'),          # hidden layer with 64 neurons
    keras.layers.Dense(32, activation='sigmoid'),          # hidden layer with 32 neurons
    keras.layers.Dense(1, activation='sigmoid')            # output layer
])

# 2️⃣ Compile the model
model_hidden_64_32.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# 3️⃣ Compute class weights
classes = np.unique(y_train)
class_weights_array = class_weight.compute_class_weight('balanced', classes=classes, y=y_train)
class_weights = {i: class_weights_array[i] for i in range(len(classes))}

# 4️⃣ Train the model
history_hidden_64_32 = model_hidden_64_32.fit(
    X_train_scaled,
    y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    class_weight=class_weights,
    verbose=1
)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.4209 - loss: 0.6848 - val_accuracy: 0.8791 - val_loss: 0.6333
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9141 - loss: 0.6128 - val_accuracy: 0.9341 - val_loss: 0.5639
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9247 - loss: 0.5408 - val_accuracy: 0.9341 - val_loss: 0.4907
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9226 - loss: 0.4782 - val_accuracy: 0.9341 - val_loss: 0.4239
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9538 - loss: 0.3770 - val_accuracy: 0.9341 - val_loss: 0.3573
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9310 - loss: 0.3344 - val_accuracy: 0.9451 - val_loss: 0.3048
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9394 - loss: 0.2946 - val_accuracy: 0.9560 - val_loss: 0.2632
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9368 - loss: 0.2544 - val_accuracy: 0.9560 - val_loss: 0.2227
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9615 - loss: 0.1966 - val_accuracy: 0.9670 - val_loss: 0.1961
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9551 - loss: 0.2066 - val_accuracy: 0.9670 - val_loss: 0.1759
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9714 - loss: 0.1638 - val_accuracy: 0.9670 - val_loss: 0.1567
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9720 - loss: 0.1676 - val_accuracy: 0.9780 - val_loss: 0.1386
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9872 - loss: 0.1273 - val_accuracy: 0.9780 - val_loss: 0.1262
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9758 - loss: 0.1152 - val_accuracy: 0.9780 - val_loss: 0.1161
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9795 - loss: 0.1214 - val_accuracy: 0.9780 - val_loss: 0.1083
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9747 - loss: 0.1313 - val_accuracy: 0.9780 - val_loss: 0.1022
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9724 - loss: 0.1349 - val_accuracy: 0.9890 - val_loss: 0.0949
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9808 - loss: 0.1017 - val_accuracy: 0.9890 - val_loss: 0.0893
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9775 - loss: 0.1135 - val_accuracy: 0.9890 - val_loss: 0.0861
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9876 - loss: 0.0737 - val_accuracy: 0.9890 - val_loss: 0.0811
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9832 - loss: 0.0825 - val_accuracy: 0.9890 - val_loss: 0.0787
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9830 - loss: 0.0774 - val_accuracy: 0.9890 - val_loss: 0.0764
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9819 - loss: 0.0748 - val_accuracy: 0.9890 - val_loss: 0.0740
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9784 - loss: 0.0895 - val_accuracy: 0.9890 - val_loss: 0.0717
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9837 - loss: 0.0728 - val_accuracy: 0.9890 - val_loss: 0.0692
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9822 - loss: 0.0745 - val_accuracy: 0.9890 - val_loss: 0.0688
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9834 - loss: 0.0647 - val_accuracy: 0.9890 - val_loss: 0.0656
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9808 - loss: 0.0780 - val_accuracy: 0.9890 - val_loss: 0.0632
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9859 - loss: 0.0679 - val_accuracy: 0.9890 - val_loss: 0.0614
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9932 - loss: 0.0452 - val_accuracy: 0.9890 - val_loss: 0.0618
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9794 - loss: 0.0833 - val_accuracy: 0.9890 - val_loss: 0.0647
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9783 - loss: 0.0793 - val_accuracy: 0.9890 - val_loss: 0.0620
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9807 - loss: 0.0677 - val_accuracy: 0.9890 - val_loss: 0.0599
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9793 - loss: 0.0840 - val_accuracy: 0.9890 - val_loss: 0.0592
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9744 - loss: 0.0824 - val_accuracy: 0.9890 - val_loss: 0.0562
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9815 - loss: 0.0705 - val_accuracy: 0.9890 - val_loss: 0.0555
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9803 - loss: 0.0728 - val_accuracy: 0.9890 - val_loss: 0.0551
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9836 - loss: 0.0667 - val_accuracy: 0.9890 - val_loss: 0.0541
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9734 - loss: 0.0778 - val_accuracy: 0.9890 - val_loss: 0.0535
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9903 - loss: 0.0508 - val_accuracy: 0.9890 - val_loss: 0.0529
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9805 - loss: 0.0722 - val_accuracy: 0.9890 - val_loss: 0.0537
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9840 - loss: 0.0770 - val_accuracy: 0.9890 - val_loss: 0.0531
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9906 - loss: 0.0433 - val_accuracy: 0.9890 - val_loss: 0.0514
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9877 - loss: 0.0529 - val_accuracy: 0.9890 - val_loss: 0.0508
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9864 - loss: 0.0587 - val_accuracy: 0.9890 - val_loss: 0.0502
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9841 - loss: 0.0576 - val_accuracy: 0.9780 - val_loss: 0.0505
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9895 - loss: 0.0430 - val_accuracy: 0.9890 - val_loss: 0.0489
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9910 - loss: 0.0380 - val_accuracy: 0.9890 - val_loss: 0.0484
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9849 - loss: 0.0636 - val_accuracy: 0.9780 - val_loss: 0.0489
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9912 - loss: 0.0415 - val_accuracy: 0.9780 - val_loss: 0.0478
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9882 - loss: 0.0590 - val_accuracy: 0.9780 - val_loss: 0.0484
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9845 - loss: 0.0522 - val_accuracy: 0.9890 - val_loss: 0.0466
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9916 - loss: 0.0553 - val_accuracy: 0.9780 - val_loss: 0.0462
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9831 - loss: 0.0528 - val_accuracy: 0.9780 - val_loss: 0.0475
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9842 - loss: 0.0546 - val_accuracy: 0.9780 - val_loss: 0.0490
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9912 - loss: 0.0374 - val_accuracy: 0.9780 - val_loss: 0.0475
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9853 - loss: 0.0571 - val_accuracy: 0.9780 - val_loss: 0.0473
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9905 - loss: 0.0373 - val_accuracy: 0.9780 - val_loss: 0.0456
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9796 - loss: 0.0752 - val_accuracy: 0.9780 - val_loss: 0.0458
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9891 - loss: 0.0383 - val_accuracy: 0.9780 - val_loss: 0.0452
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9913 - loss: 0.0426 - val_accuracy: 0.9780 - val_loss: 0.0471
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9865 - loss: 0.0640 - val_accuracy: 0.9780 - val_loss: 0.0478
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9772 - loss: 0.0835 - val_accuracy: 0.9780 - val_loss: 0.0467
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9890 - loss: 0.0459 - val_accuracy: 0.9780 - val_loss: 0.0451
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9898 - loss: 0.0550 - val_accuracy: 0.9780 - val_loss: 0.0462
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9870 - loss: 0.0528 - val_accuracy: 0.9780 - val_loss: 0.0482
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9876 - loss: 0.0453 - val_accuracy: 0.9780 - val_loss: 0.0437
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9874 - loss: 0.0476 - val_accuracy: 0.9780 - val_loss: 0.0483
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9792 - loss: 0.0810 - val_accuracy: 0.9670 - val_loss: 0.0471
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9876 - loss: 0.0460 - val_accuracy: 0.9670 - val_loss: 0.0456
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9890 - loss: 0.0377 - val_accuracy: 0.9670 - val_loss: 0.0450
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9820 - loss: 0.0794 - val_accuracy: 0.9670 - val_loss: 0.0452
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9897 - loss: 0.0504 - val_accuracy: 0.9780 - val_loss: 0.0437
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9906 - loss: 0.0469 - val_accuracy: 0.9780 - val_loss: 0.0452
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9826 - loss: 0.0843 - val_accuracy: 0.9780 - val_loss: 0.0463
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9844 - loss: 0.0416 - val_accuracy: 0.9780 - val_loss: 0.0422
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9862 - loss: 0.0535 - val_accuracy: 0.9780 - val_loss: 0.0424
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9905 - loss: 0.0418 - val_accuracy: 0.9890 - val_loss: 0.0442
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9891 - loss: 0.0384 - val_accuracy: 0.9780 - val_loss: 0.0443
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9856 - loss: 0.0589 - val_accuracy: 0.9780 - val_loss: 0.0446
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9907 - loss: 0.0513 - val_accuracy: 0.9890 - val_loss: 0.0438
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9813 - loss: 0.0661 - val_accuracy: 0.9780 - val_loss: 0.0480
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9828 - loss: 0.0563 - val_accuracy: 0.9780 - val_loss: 0.0472
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9861 - loss: 0.0651 - val_accuracy: 0.9780 - val_loss: 0.0464
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9846 - loss: 0.0781 - val_accuracy: 0.9780 - val_loss: 0.0430
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9919 - loss: 0.0374 - val_accuracy: 0.9780 - val_loss: 0.0439
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9881 - loss: 0.0426 - val_accuracy: 0.9780 - val_loss: 0.0445
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9945 - loss: 0.0316 - val_accuracy: 0.9780 - val_loss: 0.0446
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9881 - loss: 0.0434 - val_accuracy: 0.9780 - val_loss: 0.0506
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9820 - loss: 0.0403 - val_accuracy: 0.9780 - val_loss: 0.0461
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9896 - loss: 0.0324 - val_accuracy: 0.9670 - val_loss: 0.0414
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9857 - loss: 0.0750 - val_accuracy: 0.9780 - val_loss: 0.0445
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9909 - loss: 0.0315 - val_accuracy: 0.9780 - val_loss: 0.0425
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9914 - loss: 0.0396 - val_accuracy: 0.9780 - val_loss: 0.0433
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9859 - loss: 0.0413 - val_accuracy: 0.9780 - val_loss: 0.0507
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9898 - loss: 0.0534 - val_accuracy: 0.9780 - val_loss: 0.0499
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0415 - val_accuracy: 0.9780 - val_loss: 0.0437
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9928 - loss: 0.0274 - val_accuracy: 0.9780 - val_loss: 0.0421
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9904 - loss: 0.0318 - val_accuracy: 0.9780 - val_loss: 0.0432
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9873 - loss: 0.0640 - val_accuracy: 0.9780 - val_loss: 0.0427

# %%
test_loss_5, test_accuracy_5 = model_hidden_64_32.evaluate(X_test_scaled, y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9383 - loss: 0.1232

# %%
# Set a5a to the final training accuracy
# Use the appropriate variable or expression; do not insert a constant from inspection of the results

a5a =  history_hidden_64_32.history['accuracy'][-1]             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way

print(f'a5a = {a5a:.4f}')
# Out:
# a5a = 0.9890

# %%
# Set a5b to the final testing accuracy
# Use the appropriate variable; do not insert a constant from inspection of the results

a5b = test_accuracy_5             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way

print(f'a5b = {a5b:.4f}')
# Out:
# a5b = 0.9474

# %% [markdown]
# ## Reflection Questions:
#
# You won't be graded on these, and you don't need to write anything, but here are some things to think about after completing the experiments.
#
# 1. After the baseline, we tried wider and wider models, and then a deeper model. Which idea worked better in terms of training accuracy (at least for this data split)? What model would you try next to test this hypothesis?
#
# 2. What effect did these experiments have on the testing accuracy?  Can you suggest an explanation for this? Rather than me giving you ideas, have a conversation with `ChatGPT` in which you describe your experiments, and the dataset, and explore with it why the testing results turned out this way.
#
# 3. What do you think would happen if you tried running the same experiments with a different random seed (and hence a different split in a fairly small dataset)?
