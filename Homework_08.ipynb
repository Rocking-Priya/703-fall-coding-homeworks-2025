# Epoch 24/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0280 - mae: 0.1278 - rmse: 0.1673 - val_loss: 0.0199 - val_mae: 0.0966 - val_rmse: 0.1410
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 19.
# Selected epoch: 19 (min val_loss)
# Valid @ sel —  MAE: 0.09214 | RMSE: 0.1311 (scaled)
# Train @ sel —  MAE: 0.1335  | RMSE: 0.1721 (scaled)

# %% [markdown]
# ### Now we'll demonstrate the model's predictive power on the last 2 weeks of the test samples

# %%
def evaluate_on_test(
    model,
    *,
    target_scaler=None,          # pass your y scaler here if you want original units
    report_in_scaled=True,       # set False to invert to original units
    unit_scaled="(scaled)",
    unit_original="MW",          # or "MWh" if your target is energy, not power
    plot_last_hours=24*7,
):
    """
    Evaluate on X_test/y_test and plot the last `plot_last_hours` predictions.
    Supports horizon=1 and direct multi-output (H>1).
    """
    # 1) Predict
    y_pred = model.predict(X_test, verbose=0)         # (n_windows, H) or (n_windows, 1)
    if y_pred.ndim == 1:
        y_pred = y_pred[:, None]
    H = y_pred.shape[1]

    # 2) Choose units (scaled vs original)
    def maybe_invert(arr):
        if report_in_scaled or target_scaler is None:
            return arr
        a = np.asarray(arr).reshape(-1, 1)
        return target_scaler.inverse_transform(a).ravel()

    # 3) Build comparable arrays for metrics
    # y_test matches y_pred shape: (n_windows, H)
    y_true = y_test
    # Metrics (per-horizon and averaged) in chosen units
    err = maybe_invert(y_pred.ravel()) - maybe_invert(y_true.ravel())
    rmse_avg = float(np.sqrt(np.mean(err**2)))
    mae_avg  = float(np.mean(np.abs(err)))

    if H > 1:
        # per-horizon
        y_true_u = maybe_invert(y_true)
        y_pred_u = maybe_invert(y_pred)
        mae_per_h  = np.mean(np.abs(y_true_u - y_pred_u), axis=0)
        rmse_per_h = np.sqrt(np.mean((y_true_u - y_pred_u)**2, axis=0))

    # 4) Prepare a single timeline for plotting
    def stitch_direct_predictions(yhat):
        """Average overlaps for direct multi-step predictions."""
        n, HH = yhat.shape
        total = n + HH - 1
        out = np.zeros(total, dtype=float)
        cnt = np.zeros(total, dtype=float)
        for i in range(n):
            out[i:i+HH] += yhat[i]
            cnt[i:i+HH] += 1.0
        return out / np.maximum(cnt, 1.0)

    # Choose units for plotting
    unit = unit_scaled if (report_in_scaled or target_scaler is None) else unit_original

    if H == 1:
        y_true_t = maybe_invert(y_true.ravel())
        y_pred_t = maybe_invert(y_pred.ravel())
    else:
        # stitch both for a continuous timeline
        y_pred_t = stitch_direct_predictions(maybe_invert(y_pred))
        y_true_t = stitch_direct_predictions(maybe_invert(y_true))

    # 5) Print summary
    print(f"Test RMSE (avg over all steps): {rmse_avg:,.3f} {unit}")
    print(f"Test  MAE (avg over all steps): {mae_avg:,.3f} {unit}")
    if H > 1:
        print("Per-horizon (0 = 1-step ahead):")
        print("  MAE :", np.round(mae_per_h, 3))
        print("  RMSE:", np.round(rmse_per_h, 3))

    # 6) Plot last N hours
    N = min(plot_last_hours, len(y_true_t))
    plt.figure(figsize=(14, 6))
    plt.title("Test — Last 7 Days: Truth vs Forecast")
    plt.plot(y_true_t[-N:], label="Truth")
    plt.plot(y_pred_t[-N:], label="Predicted", linestyle="--")
    plt.xlabel("Hour")
    plt.ylabel(unit)
    plt.grid(True, axis='y', linestyle=':', alpha=0.6)
    plt.legend()
    plt.tight_layout()
    plt.show()

evaluate_on_test(baseline_model)
# Out:
# Test RMSE (avg over all steps): 0.097 (scaled)
# Test  MAE (avg over all steps): 0.081 (scaled)

# %% [markdown]
# ## Problem One — Exploring Lookback and Horizon
#
# Experiment with different combinations of `lookback` and `horizon` values.
# For example, you might double the lookback window (e.g., from 1 week to 2 weeks) or extend the prediction horizon to 24 hours.
#
# After each change:
# - Retrain your model.
# - Use `evaluate_on_test(...)` to visualize the extended 2-week prediction.
# - Compare validation and test MAE/RMSE across experiments.
# - Answer the graded questions.
#
# > *Note:* You’ll need to adjust the data-preparation cell above to rebuild the training, validation, and testing sets with the new parameters.

# %%
# Your code here, add as many cells as you like

# experiment grid (adjust as you like)
lookbacks = [7*24, 14*24, 3*24]   # 1 week, 2 weeks, 3 days
horizons  = [1, 6, 24]            # next-hour, 6-hour, 24-hour

exp_results = []  # list of dicts

def build_baseline(lookback, horizon, lstm_units=32, dropout=0.2):
    model = Sequential([
        Input(shape=(lookback, 1)),
        LSTM(lstm_units),
        Dropout(dropout),
        Dense(16, activation="relu", kernel_initializer=he),
        Dense(horizon)
    ])
    return model

# iterate
for lb in lookbacks:
    for h in horizons:
        print(f"\n--- Experiment: lookback={lb} hours, horizon={h} hours ---")

        # rebuild windows for this lookback/horizon
        X_train, y_train = make_windows(train_x, lookback=lb, horizon=h)
        X_val,   y_val   = make_windows(val_x,   lookback=lb, horizon=h)
        X_test,  y_test  = make_windows(test_x,  lookback=lb, horizon=h)

        print(f"Shapes -> X_train: {X_train.shape}, X_val: {X_val.shape}, X_test: {X_test.shape}")

        # build and train
        model = build_baseline(lb, h)
        history, test_results, info = train_and_test(
            model,
            X_train=X_train, y_train=y_train,
            X_val=X_val,     y_val=y_val,
            X_test=X_test,   y_test=y_test,
            epochs=50, batch_size=64, patience=6,
            lr_schedule=1e-3,
            return_history=True,
            verbose=0,  # set 1 to see training
            title=f"LSTM lb={lb} h={h}"
        )

        # selected epoch index
        sel_idx = info["selected_epoch"] - 1

        # validation MAE at selected epoch (if available)
        val_mae = None
        if "val_mae" in history.history and len(history.history["val_mae"]) > sel_idx:
            val_mae = float(history.history["val_mae"][sel_idx])
        else:
            # fall back: compute val MAE manually
            y_pred_val = model.predict(X_val)
            val_mae = float(np.mean(np.abs(y_pred_val.ravel() - y_val.ravel())))

        # validation RMSE at selected epoch if available
        val_rmse = None
        if "val_rmse" in history.history and len(history.history["val_rmse"]) > sel_idx:
            val_rmse = float(history.history["val_rmse"][sel_idx])
        else:
            y_pred_val = model.predict(X_val)
            val_rmse = float(np.sqrt(np.mean((y_pred_val.ravel() - y_val.ravel())**2)))

        # store
        exp_results.append({
            "lookback": lb,
            "horizon": h,
            "val_mae_at_min_valloss": val_mae,
            "val_rmse_at_min_valloss": val_rmse,
            "selected_epoch": info["selected_epoch"],
            "test_results": test_results,
        })

        # quick print
        print(f"Selected epoch: {info['selected_epoch']}, val MAE: {val_mae:.5f}, val RMSE: {val_rmse:.5f}")

# summarize experiments sorted by val_mae
exp_results_sorted = sorted(exp_results, key=lambda x: x["val_mae_at_min_valloss"])
for r in exp_results_sorted:
    print(f"lb={r['lookback']:4d}, h={r['horizon']:2d}  -> val_MAE={r['val_mae_at_min_valloss']:.5f} | val_RMSE={r['val_rmse_at_min_valloss']:.5f}")
# Out:
# --- Experiment: lookback=168 hours, horizon=1 hours ---
# Shapes -> X_train: (2368, 168, 1), X_val: (375, 168, 1), X_test: (377, 168, 1)
#
# LSTM lb=168 h=1
# Selected epoch: 20, val MAE: 0.08593, val RMSE: 0.12763
#
# --- Experiment: lookback=168 hours, horizon=6 hours ---
# Shapes -> X_train: (2363, 168, 1), X_val: (370, 168, 1), X_test: (372, 168, 1)
#
# LSTM lb=168 h=6
# Selected epoch: 47, val MAE: 0.27376, val RMSE: 0.35244
#
# --- Experiment: lookback=168 hours, horizon=24 hours ---
# Shapes -> X_train: (2345, 168, 1), X_val: (352, 168, 1), X_test: (354, 168, 1)
#
# LSTM lb=168 h=24
# Selected epoch: 28, val MAE: 0.35321, val RMSE: 0.42619
#
# --- Experiment: lookback=336 hours, horizon=1 hours ---
# Shapes -> X_train: (2200, 336, 1), X_val: (207, 336, 1), X_test: (209, 336, 1)
#
# LSTM lb=336 h=1
# Selected epoch: 17, val MAE: 0.10224, val RMSE: 0.15253
#
# --- Experiment: lookback=336 hours, horizon=6 hours ---
# Shapes -> X_train: (2195, 336, 1), X_val: (202, 336, 1), X_test: (204, 336, 1)
#
# LSTM lb=336 h=6
# Selected epoch: 18, val MAE: 0.32079, val RMSE: 0.38928
#
# --- Experiment: lookback=336 hours, horizon=24 hours ---
# Shapes -> X_train: (2177, 336, 1), X_val: (184, 336, 1), X_test: (186, 336, 1)
#
# LSTM lb=336 h=24
# Selected epoch: 25, val MAE: 0.34193, val RMSE: 0.41055
#
# --- Experiment: lookback=72 hours, horizon=1 hours ---
# Shapes -> X_train: (2464, 72, 1), X_val: (471, 72, 1), X_test: (473, 72, 1)
#
# LSTM lb=72 h=1
# Selected epoch: 17, val MAE: 0.09897, val RMSE: 0.13642
#
# --- Experiment: lookback=72 hours, horizon=6 hours ---
# Shapes -> X_train: (2459, 72, 1), X_val: (466, 72, 1), X_test: (468, 72, 1)
#
# LSTM lb=72 h=6
# Selected epoch: 50, val MAE: 0.29039, val RMSE: 0.40112
#
# --- Experiment: lookback=72 hours, horizon=24 hours ---
# Shapes -> X_train: (2441, 72, 1), X_val: (448, 72, 1), X_test: (450, 72, 1)
#
# LSTM lb=72 h=24
# Selected epoch: 35, val MAE: 0.36971, val RMSE: 0.45622
# lb= 168, h= 1  -> val_MAE=0.08593 | val_RMSE=0.12763
# lb=  72, h= 1  -> val_MAE=0.09897 | val_RMSE=0.13642
# lb= 336, h= 1  -> val_MAE=0.10224 | val_RMSE=0.15253
# lb= 168, h= 6  -> val_MAE=0.27376 | val_RMSE=0.35244
# lb=  72, h= 6  -> val_MAE=0.29039 | val_RMSE=0.40112
# lb= 336, h= 6  -> val_MAE=0.32079 | val_RMSE=0.38928
# lb= 336, h=24  -> val_MAE=0.34193 | val_RMSE=0.41055
# lb= 168, h=24  -> val_MAE=0.35321 | val_RMSE=0.42619
# lb=  72, h=24  -> val_MAE=0.36971 | val_RMSE=0.45622

# %% [markdown]
# ### Graded Questions

# %%
# Set a1 to the Validation MAE at the epoch of minimum validation loss (mse) for your best choices of lookback and horizon

a1a = 0.085930             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way

print(f'a1a = {a1a:.4f}')
# Out:
# a1a = 0.0859

# %% [markdown]
# #### Question a1b: Describe below your experiments. What effect did your changes to the lookback and horizon have? Did you get an improvement in the validation MAE?
#
# #### Your Answer Here:

# %% [markdown]
# I tested different combinations of lookback windows (3 days = 72 hours, 1 week = 168 hours, and 2 weeks = 336 hours) and prediction horizons (1 hour, 6 hours, and 24 hours).
#
# When the lookback increased from 3 days (72 hrs) to 1 week (168 hrs), the validation MAE improved — it dropped from 0.09897 to 0.08593 for the 1-hour horizon.
# This means the model learned better patterns when it had about one week of past data.
#
# However, when I doubled the lookback again to 2 weeks (336 hrs), the validation MAE got slightly worse (0.10224), showing that too much history did not help and may have caused mild overfitting.
#
# When I increased the horizon (future prediction window) from 1 hour → 6 hours → 24 hours, the MAE and RMSE both increased for all lookbacks.
# For example, with a 1-week lookback, MAE went from 0.08593 (1-hour) to 0.27376 (6-hour) and 0.35321 (24-hour).
# This means predicting farther into the future is harder and less accurate.
#
# Overall, the best validation MAE came from the 1-week lookback and 1-hour horizon (MAE = 0.08593).
# Increasing lookback helped up to one week, but longer lookback or longer prediction horizon made the model less accurate.

# %% [markdown]
# ## Problem Two — Architectural Tweaks
#
# Using the best lookback and horizon from Problem 1 (or the original defaults if they performed better),
# experiment with at least **one architectural change**.
#
# Possible options:
# - Add a deeper “head” (e.g., extra Dense layers)
# - Stack another LSTM layer
# - Try a **Bidirectional LSTM** (it processes the past window in both forward and backward directions—no future leakage!)
#
# Train, evaluate, and answer the graded questions.

# %%
# Your code here, add as many cells as you like
# Problem 2 — Architectural Tweaks
# Using the best lookback and horizon from Problem 1

best_lookback = 168   # 1 week
best_horizon = 1      # 1 hour

# Rebuild the training, validation, and test sets
X_train, y_train = make_windows(train_x, lookback=best_lookback, horizon=best_horizon)
X_val,   y_val   = make_windows(val_x,   lookback=best_lookback, horizon=best_horizon)
X_test,  y_test  = make_windows(test_x,  lookback=best_lookback, horizon=best_horizon)

print(f"Shapes -> X_train: {X_train.shape}, X_val: {X_val.shape}, X_test: {X_test.shape}")

# Build a Bidirectional LSTM model
model2 = Sequential([
    Input(shape=(best_lookback, 1)),
    Bidirectional(LSTM(32, return_sequences=False)),  # Bidirectional layer
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(best_horizon)
])

# Train and evaluate
history2, test_results2, info2 = train_and_test(
    model2,
    X_train=X_train, y_train=y_train,
    X_val=X_val,     y_val=y_val,
    X_test=X_test,   y_test=y_test,
    epochs=50, batch_size=64, patience=6,
    lr_schedule=1e-3,
    return_history=True,
    verbose=1,
    title="Bidirectional LSTM Model"
)

# Get validation MAE at the epoch with minimum validation loss
sel_idx2 = info2["selected_epoch"] - 1
val_mae2 = float(history2.history["val_mae"][sel_idx2])
print(f"Selected epoch: {info2['selected_epoch']}, Validation MAE: {val_mae2:.5f}")

# Store this value in a2a
a2a = val_mae2
# Out:
# Shapes -> X_train: (2368, 168, 1), X_val: (375, 168, 1), X_test: (377, 168, 1)
#
# Bidirectional LSTM Model
#
# Epoch 1/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 0.6338 - mae: 0.6367 - rmse: 0.7903 - val_loss: 0.2399 - val_mae: 0.4262 - val_rmse: 0.4898
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.2517 - mae: 0.4210 - rmse: 0.5009 - val_loss: 0.1552 - val_mae: 0.3430 - val_rmse: 0.3939
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.1478 - mae: 0.3116 - rmse: 0.3844 - val_loss: 0.0962 - val_mae: 0.2652 - val_rmse: 0.3101
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.1134 - mae: 0.2718 - rmse: 0.3366 - val_loss: 0.0660 - val_mae: 0.2133 - val_rmse: 0.2569
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0890 - mae: 0.2389 - rmse: 0.2983 - val_loss: 0.0457 - val_mae: 0.1752 - val_rmse: 0.2138
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.
# Epoch 30/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0175 - mae: 0.1030 - rmse: 0.1323 - val_loss: 0.0119 - val_mae: 0.0698 - val_rmse: 0.1093
# Epoch 31/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0167 - mae: 0.0996 - rmse: 0.1292 - val_loss: 0.0119 - val_mae: 0.0687 - val_rmse: 0.1090
# Epoch 32/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0181 - mae: 0.1032 - rmse: 0.1345 - val_loss: 0.0121 - val_mae: 0.0701 - val_rmse: 0.1100
# Epoch 33/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0167 - mae: 0.0986 - rmse: 0.1293 - val_loss: 0.0135 - val_mae: 0.0765 - val_rmse: 0.1160
# Epoch 34/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0172 - mae: 0.1006 - rmse: 0.1311 - val_loss: 0.0122 - val_mae: 0.0707 - val_rmse: 0.1104
# Epoch 35/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0186 - mae: 0.1050 - rmse: 0.1364 - val_loss: 0.0131 - val_mae: 0.0754 - val_rmse: 0.1143
# Epoch 36/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0168 - mae: 0.0985 - rmse: 0.1294 - val_loss: 0.0125 - val_mae: 0.0735 - val_rmse: 0.1118
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 30.
# Selected epoch: 31 (min val_loss)
# Valid @ sel —  MAE: 0.06869 | RMSE: 0.109 (scaled)
# Train @ sel —  MAE: 0.1  | RMSE: 0.1288 (scaled)
# Selected epoch: 31, Validation MAE: 0.06869

# %%
print(val_mae2)
# Out:
# 0.06869053095579147

# %% [markdown]
# ### Graded Questions

# %%
# Set a1 to the Validation MAE at the epoch of minimum validation loss (mse)

a2a = 0.06869053095579147             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way

print(f'a2a = {a2a:.4f}')
# Out:
# a2a = 0.0687

# %% [markdown]
# #### Question a2b: Describe below your experiments and what you observed. Did you get a better validation MAE through architectural changes?
#
# #### Your Answer Here:

# %% [markdown]
# I used the best lookback and horizon from Problem 1 (lookback = 168 hours, horizon = 1 hour) and built a Bidirectional LSTM model.
# This model reads the input sequence both forward and backward, which helps it learn more temporal patterns from the data.
#
# Compared to the previous single LSTM model, the validation MAE improved from 0.08593 → 0.06869.
# The validation loss and MAE decreased steadily until around epoch 30, where early stopping selected the best model.
# This shows the bidirectional structure helped the model understand time dependencies better and predict more accurately.
#
# Overall, the Bidirectional LSTM gave a better validation MAE, meaning the architectural change improved the model’s performance.

# %% [markdown]
# ## Problem Three — Autoregressive Forecasting (ChatGPT Discussion)
#
# In this final problem, you’ll explore **autoregressive forecasting**, where the model predicts one step ahead and feeds that prediction back as input to generate the next step.
#
# **Your task:**
# 1. Briefly describe your current model to ChatGPT (e.g., “My LSTM predicts the next 24 hours directly from the past 168 hours.”), or share a short code snippet.
# 2. Ask ChatGPT how to modify it so that it instead predicts **one hour ahead**, then reuses that prediction recursively for **24 steps**.
# 3. Implement or outline the version it suggests.
# 4. Answer the graded question.

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error

# ---------- Helper: reuse your recursive_forecast ---------
def recursive_forecast(model, last_window, n_steps=24):
    preds = []
    current_input = last_window.copy()                # shape: (lookback, 1)
    for step in range(n_steps):
        # model.predict expects shape (1, lookback, 1)
        next_pred = model.predict(current_input[np.newaxis, :, :], verbose=0)[0, 0]
        preds.append(next_pred)
        # shift and append (keep shape (lookback,1))
        current_input = np.concatenate([current_input[1:], np.array([[next_pred]], dtype=current_input.dtype)], axis=0)
    return np.array(preds)   # scaled units

# ---------- Build true multi-step targets from contiguous scaled test series ----------
def build_true_multi_from_series(scaled_series_array, lookback, steps):
    arr = np.asarray(scaled_series_array).reshape(-1,1)
    n = len(arr)
    windows = []
    # windows correspond to starting positions used by make_windows: i from lookback .. n-steps
    for i in range(lookback, n - steps + 1):
        windows.append(arr[i:i+steps, 0])
    return np.array(windows, dtype=float)  # shape (n_windows, steps)

# ---------- Parameters (adjust names if your variables differ) ----------
lookback = 168
steps = 24

# Ensure you have the contiguous scaled test array (test_x is usually the contiguous series scaled)
# If your `test_x` is shaped (N_test_hours, 1) use it directly; if it's already windowed, you need the raw series.
# Here we assume `test_x` is the contiguous scaled array (same as earlier in notebook).
try:
    contiguous_test_arr = test_x.reshape(-1, 1)   # test_x was created by scaler.transform(test)
except Exception:
    # If test_x is windows, try to reconstruct from 'test' pandas slice:
    contiguous_test_arr = test.values.reshape(-1,1)  # fallback if you still have `test` series

# Build true matrix (n_windows, 24)
y_true_multi = build_true_multi_from_series(contiguous_test_arr, lookback, steps)
n_windows = y_true_multi.shape[0]
print(f"Number of starting windows for autoreg eval: {n_windows}")

# ---------- Generate AR forecasts for every starting window ----------
# If X_test currently holds windows of shape (n_windows, lookback, 1), we can reuse those as starts:
starts = X_test.copy()
if starts.shape[0] != n_windows:
    # Rebuild starts: for safety, create starts from contiguous_test_arr
    starts = []
    for i in range(lookback, len(contiguous_test_arr) - steps + 1):
        starts.append(contiguous_test_arr[i-lookback:i, 0])
    starts = np.array(starts, dtype=float)[..., None]  # (n_windows, lookback, 1)

# Choose the model to use: replace `model` with your one-step model variable if needed
one_step_model = model  # or model2 / one_step_model etc.

# Run autoregressive forecasts in batches to save time
yhat_ar = np.zeros((n_windows, steps), dtype=float)
for i in range(n_windows):
    yhat_ar[i] = recursive_forecast(one_step_model, starts[i,:, :], n_steps=steps)

# ---------- Optionally invert to original units ----------
report_in_original = False
if report_in_original and ('scaler' in globals()):
    # scaler expects shape (-1,1)
    yhat_ar_u = scaler.inverse_transform(yhat_ar.reshape(-1,1)).reshape(n_windows, steps)
    y_true_u  = scaler.inverse_transform(y_true_multi.reshape(-1,1)).reshape(n_windows, steps)
else:
    yhat_ar_u = yhat_ar
    y_true_u  = y_true_multi

# ---------- Compute per-horizon MAE & RMSE ----------
per_h_mae = np.mean(np.abs(y_true_u - yhat_ar_u), axis=0)
per_h_rmse = np.sqrt(np.mean((y_true_u - yhat_ar_u)**2, axis=0))

print("Autoregressive per-horizon errors (scaled units unless inverted):")
for h in range(steps):
    print(f"H={h+1:2d}: MAE={per_h_mae[h]:.5f}, RMSE={per_h_rmse[h]:.5f}")

# ---------- Optional direct comparison if you have direct y_test_24 (n_windows,24) ----------
if 'y_test_24' in globals() and y_test_24.shape == yhat_ar.shape:
    # y_test_24 may already be in scaled units
    direct_per_h_mae = np.mean(np.abs(y_test_24 - yhat_ar), axis=0)  # direct vs AR
    print("\nDirect vs Autoregressive (per-horizon MAE):")
    for h in range(steps):
        print(f"H={h+1:2d}: Direct MAE={direct_per_h_mae[h]:.5f} | AR MAE={per_h_mae[h]:.5f}")
else:
    print("\nNote: direct multi-output y_test_24 not found in globals; construct it when you run the direct H=24 experiment to compare fairly.")
# Out:
# Number of starting windows for autoreg eval: 354
# Autoregressive per-horizon errors (scaled units unless inverted):
# H= 1: MAE=0.24586, RMSE=0.31167
# H= 2: MAE=0.29379, RMSE=0.37020
# H= 3: MAE=0.33014, RMSE=0.41524
# H= 4: MAE=0.35473, RMSE=0.44520
# H= 5: MAE=0.37032, RMSE=0.46353
# H= 6: MAE=0.37854, RMSE=0.47307
# H= 7: MAE=0.38268, RMSE=0.47769
# H= 8: MAE=0.38585, RMSE=0.48084
# H= 9: MAE=0.38962, RMSE=0.48462
# H=10: MAE=0.39235, RMSE=0.48850
# H=11: MAE=0.39221, RMSE=0.49093
# H=12: MAE=0.38955, RMSE=0.49252
# H=13: MAE=0.38599, RMSE=0.49458
# H=14: MAE=0.38303, RMSE=0.49676
# H=15: MAE=0.38168, RMSE=0.49872
# H=16: MAE=0.38112, RMSE=0.49885
# H=17: MAE=0.38048, RMSE=0.49701
# H=18: MAE=0.37868, RMSE=0.49309
# H=19: MAE=0.37597, RMSE=0.48861
# H=20: MAE=0.37263, RMSE=0.48436
# H=21: MAE=0.37052, RMSE=0.48135
# H=22: MAE=0.37092, RMSE=0.47994
# H=23: MAE=0.37425, RMSE=0.48100
# H=24: MAE=0.38060, RMSE=0.48525
#
# Note: direct multi-output y_test_24 not found in globals; construct it when you run the direct H=24 experiment to compare fairly.

# %% [markdown]
# ### Graded Questions

# %% [markdown]
# #### Question a3: Answer the graded questions comparing the recursive and direct approaches:
#    - Does the error grow with horizon in the autoregressive version?
#    - Which approach you tried in this homework performs better overall?
#
# #### Your Answer Here:

# %% [markdown]
# Does the error grow with horizon in the autoregressive version?
# ✅ Answer: Yes, the error generally grows as the forecast horizon increases.
#
# From the results:
#
# H=1: MAE=0.24586, RMSE=0.31167
#
# H=12: MAE=0.38955, RMSE=0.49252
#
# H=24: MAE=0.38060, RMSE=0.48525
#
# This is typical of autoregressive (recursive) forecasting because each step depends on previous predictions; errors can accumulate over longer horizons.
#
# Which approach performs better overall?
# ✅ Answer: The direct multi-output approach usually performs better for longer horizons.
#
# Reason: The direct approach predicts each horizon independently, so it does not accumulate errors like the recursive approach.
#
# In your homework, the recursive (AR) version shows increasing error with horizon, while the direct H=24 approach (if you had it) would likely have smaller MAE/RMSE for steps further out.

# %%
print_results()
# Out:
# Bidirectional LSTM Model             val_RMSE@min_val_loss=0.109 | val_MAE@min_val_loss=0.06869 | epoch=31  (scaled)
# LSTM lb=168 h=1                      val_RMSE@min_val_loss=0.1276 | val_MAE@min_val_loss=0.08593 | epoch=20  (scaled)
# Baseline Model                       val_RMSE@min_val_loss=0.1311 | val_MAE@min_val_loss=0.09214 | epoch=19  (scaled)
# LSTM lb=72 h=1                       val_RMSE@min_val_loss=0.1364 | val_MAE@min_val_loss=0.09897 | epoch=17  (scaled)
# LSTM lb=336 h=1                      val_RMSE@min_val_loss=0.1525 | val_MAE@min_val_loss=0.1022 | epoch=17  (scaled)
# LSTM lb=168 h=6                      val_RMSE@min_val_loss=0.3524 | val_MAE@min_val_loss=0.2738 | epoch=47  (scaled)
# LSTM lb=336 h=6                      val_RMSE@min_val_loss=0.3893 | val_MAE@min_val_loss=0.3208 | epoch=18  (scaled)
# LSTM lb=72 h=6                       val_RMSE@min_val_loss=0.4011 | val_MAE@min_val_loss=0.2904 | epoch=50  (scaled)
# LSTM lb=336 h=24                     val_RMSE@min_val_loss=0.4105 | val_MAE@min_val_loss=0.3419 | epoch=25  (scaled)
# LSTM lb=168 h=24                     val_RMSE@min_val_loss=0.4262 | val_MAE@min_val_loss=0.3532 | epoch=28  (scaled)
# LSTM lb=72 h=24                      val_RMSE@min_val_loss=0.4562 | val_MAE@min_val_loss=0.3697 | epoch=35  (scaled)
